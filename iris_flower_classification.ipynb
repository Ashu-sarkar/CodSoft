# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashu-sarkar/CodSoft/blob/main/iris_flower_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # iris-flower-classification
#
# Use the "Run" button to execute the code.

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris_data = pd.read_csv('/content/iris.csv')

# %%
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# Data of first 5 Rows

iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Data of Last 5 Rows

iris_data.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
# To know more about the data

iris_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris_data.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
# Checking for unique data
iris_data.nunique
# Out:
# <bound method DataFrame.nunique of      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
# Restructuring the dataset for better processing

iris_data_updated = iris_data.rename(columns={'sepal length in cm': 'sepal_length','petal length in cm': 'petal_length','sepal width in cm': 'sepal_width','petal width in cm': 'petal width', 'class': 'species'})

# %%
iris_data_updated
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Using graphs for bettter understanding of the presented data

# %%
sns.lineplot(x = iris_data_updated["sepal_length"], y=iris_data_updated["petal_length"])
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
# Understanding the relationship between sepal length and petal length
sns.scatterplot(x=iris_data_updated["sepal_length"], y =iris_data_updated["petal_length"])
plt.title("sepal length vs petal length")
# Out:
# Text(0.5, 1.0, 'sepal length vs petal length')

# %%
# Understanding the relationship between sepal width and petal widt

plt.plot(iris_data_updated['sepal_width'])
plt.plot(iris_data_updated['petal_width'])
plt.legend(["sepal_width" , "petal_width"])

# %%
# Plotting all the features

plt.plot(iris_data_updated['sepal_width'])
plt.plot(iris_data_updated['petal_width'])
plt.plot(iris_data_updated['sepal_length'])
plt.plot(iris_data_updated['petal_length'])
plt.legend(['sepal_width', "petal_width", "sepal_length", "petal_width"])
plt.rcParams["figure.figsize"] = (16,6)

# %%
sns.lmplot(x ="sepal_length", y ="sepal_width", data = iris_data_updated, hue='species', legend=False)
plt.legend(["sepal_width", "sepal_length"])

# %% [markdown]
# # Comparing the species of each type

# %%
fig,axes = plt.subplots(2,2,figsize = (16,5))
plt.subplots_adjust(left = 0.1, bottom = 0.1, right = 0.9, top = 1)
sns.barplot(x = iris_data_updated['species'], y = iris_data_updated["sepal_length"], palette = "cool", ax=axes[0][0]).set_title('species vs sepal_length')
sns.barplot(x = iris_data_updated['species'], y = iris_data_updated["sepal_width"], palette = "CMRmap_r", ax=axes[1][0]).set_title('species vs sepal_length')
sns.barplot(x = iris_data_updated['species'], y = iris_data_updated["petal_length"], palette = "cool", ax=axes[0][1]).set_title('species vs petal_length')
sns.barplot(x = iris_data_updated['species'], y = iris_data_updated["petal_width"], palette = "CMRmap_r", ax=axes[1][1]).set_title('species vs petal_width')
# Out:
# Text(0.5, 1.0, 'species vs petal_width')

# %%
# Correlation of the above presented data
correlation = iris_data_updated.corr()
# Out:
# <ipython-input-46-c6262ae70548>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = iris_data_updated.corr()

# %%
sns.heatmap(correlation,annot = True,cmap = "CMRmap_r")
plt.rcParams["figure.figsize"]=(5,5)

# %%
# Cleaning of Duplicate Data]

iris_data_updated[iris_data_updated.duplicated()]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 34            4.9          3.1           1.5          0.1     Iris-setosa
# 37            4.9          3.1           1.5          0.1     Iris-setosa
# 142           5.8          2.7           5.1          1.9  Iris-virginica

# %%
# Delete the Duplicated Data

iris_data_updated.drop_duplicates(inplace = True)
iris_data_updated.shape
# Out:
# (147, 5)

# %% [markdown]
# # Model Implementation

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
iris_data_updated['species'] = label_encoder.fit_transform(iris_data_updated['species'])

iris_data_updated['species'].unique()
# Out:
# array([0, 1, 2])

# %%
# Splitting Data
from sklearn.model_selection import train_test_split
x = iris_data_updated.drop(['species'], axis = 1) # independent variable

y = iris_data_updated['species'] # dependent variable

# %%
x_sepal_train, x_sepal_test, y_species_train, y_species_test = train_test_split(x,y,random_state = 10, test_size=0.3)

# %%
x_sepal_train, x_sepal_test, y_species_train, y_species_test.shape
# Out:
# (     sepal_length  sepal_width  petal_length  petal_width
#  143           6.8          3.2           5.9          2.3
#  128           6.4          2.8           5.6          2.1
#  14            5.8          4.0           1.2          0.2
#  85            6.0          3.4           4.5          1.6
#  20            5.4          3.4           1.7          0.2
#  ..            ...          ...           ...          ...
#  115           6.4          3.2           5.3          2.3
#  66            5.6          3.0           4.5          1.5
#  15            5.7          4.4           1.5          0.4
#  127           6.1          3.0           4.9          1.8
#  9             4.9          3.1           1.5          0.1
#
#  [102 rows x 4 columns],
#       sepal_length  sepal_width  petal_length  petal_width
#  126           6.2          2.8           4.8          1.8
#  97            6.2          2.9           4.3          1.3
# ...

# %%
x_sepal_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 143           6.8          3.2           5.9          2.3
# 128           6.4          2.8           5.6          2.1
# 14            5.8          4.0           1.2          0.2
# 85            6.0          3.4           4.5          1.6
# 20            5.4          3.4           1.7          0.2
# ..            ...          ...           ...          ...
# 115           6.4          3.2           5.3          2.3
# 66            5.6          3.0           4.5          1.5
# 15            5.7          4.4           1.5          0.4
# 127           6.1          3.0           4.9          1.8
# 9             4.9          3.1           1.5          0.1
#
# [102 rows x 4 columns]

# %%
# Applying Linear Regression Model

from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# Feeding Data into Model

model.fit(x_sepal_train, y_species_train)
y_species_predicted = model.predict(x_sepal_test)

# %%
# Accuracy of Linear Regression Model

from sklearn.metrics import accuracy_score

sc_lr = round(model.score(x_sepal_test, y_species_test) * 100, 2)
print("Accuracy", str(sc_lr), "%")
# Out:
# Accuracy 90.01 %

# %%
# Applying Logistic Regression Model

from sklearn.linear_model import LogisticRegression
logistic_model = LogisticRegression(max_iter = 130)
logistic_model.fit(x_sepal_train,y_species_train)

LogisticRegression(max_iter= 130)

y_species_logistic_predicted = logistic_model.predict(x_sepal_test)

# %%
sc_lr = round(model.score(x_sepal_test, y_species_test) * 100, 2)
print("Accuracy", str(sc_lr), "%")
# Out:
# Accuracy 90.01 %

# %% [markdown]
# # Testing of the above Model

# %%
X_new = np.array([[3, 2, 1, 0.2], [  4.9, 2.2, 3.8, 1.1 ], [  5.3, 2.5, 4.6, 1.9 ]])
#Prediction of the species from the input vector
prediction = logistic_model.predict(X_new)
print("Prediction of Species: {}".format(prediction))
# Out:
# Prediction of Species: [0 1 1]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
sc_logr = round(logistic_model.score(x_sepal_test, y_species_test) * 100,2)
print("Accuracy: ", str(sc_logr) , "%")
# Out:
# Accuracy:  91.11 %
